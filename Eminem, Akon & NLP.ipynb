# %% [markdown]
# # Eminem, Akon & NLP
# ## I use NLTK to perform stemming, lemmatiziation, tokenization, stop word removal on a dataset of my choice
#
# I stumbled upon this [interesting piece](https://genius.com/a/akon-explains-how-eminem-treats-recording-music-like-a-nine-to-five-job) on Genius where "Akon Explains How Eminem Treats Recording Music Like A Nine-To-Five Job". I'll scrape this and use it as my dataset.
#
# ## Getting the Data

# %%
# Web scraping, pickle imports
import requests
from bs4 import BeautifulSoup

page = requests.get('https://genius.com/a/akon-explains-how-eminem-treats-recording-music-like-a-nine-to-five-job').text # Get all data from URL
soup = BeautifulSoup(page, "lxml") # Read as an HTML document
text = [p.text for p in soup.find(class_="article_rich_text_formatting").find_all('p')] # Pull out all text from the class article_rich_text_formatting. Creates a list of <p> paragraphs

text # Let's look at the data
# Out:
# ['Back in 2006, Akon recruited Eminem for “Smack That,” the first single from his sophomore album, Konvicted. In a recent interview with Hot 97’s Ebro in the Morning, the Senegalese-American singer provided a look into the Detroit rapper’s 9-to-5 recording schedule.',
#  '“Working with him made me look at the business different because he was the first artist that I worked with that actually treated the business like a real job,” Akon explained. “He comes in at 9 a.m. every day to the studio, takes his lunch break at 1, and is out of there by 5 p.m. It’s like a schedule.”',
#  'Not anticipating Em’s strict schedule, Akon showed up on the first day at 6 p.m., only to find out that the Shady Records co-founder had already left for the day. After Em told him to arrive at the studio at 9 a.m. the next day, Akon recalled how Em immediately paused working not only for lunch, but at the end of the day as well.',
#  "“I’m in the middle of writing a record, and he’s like, ‘Yo, I’m about to go out for lunch,’” Akon remembered. “He goes, takes his lunch [for] an hour, come back. He’s back, ‘What we got?’ I play him the record, play him the chorus, he’s like, ‘This is it. Boom.’ He goes into his verse. 5 o'clock come, he’s halfway in. He’s like, ‘Alright, bro. I'ma see you tomorrow.’”",
#  'When Em returned the next day to wrap up his verse, Akon naturally asked the legendary MC about his unorthodox approach to recording. According to Akon, Em responded:',
#  'Nah, man. I just like to be here. I treat it like a real job. I don’t make it no more than what it’s supposed to be. I don’t allow it to stress me out, stay longer than I have to. I got a family, I got a daughter I wanna be spending time with her. I wanna make time.',
#  'Hearing Em’s explanation resonated with Akon, who has now adjusted his perspective on studio time. “I’m sitting there like, ‘That makes a lot sense. Ain’t nothing gonna change between today and tomorrow,’” said Akon. “I hit him up, I said, ‘You just gave me a whole new outlook on how to treat the business from the creative end of it.’ ‘Cause now I create the schedule going in and I do it when time permits for it, but I don’t force it no more like I used to.”',
#  '',
#  '“Smack That” became one of Akon’s four Top 10 hits from Konvicted. The collaboration peaked at No. 2 on the Billboard Hot 100, making it Eminem’s highest-charting featured appearance. The track was later certified double Platinum in December 2007.',
#  'Watch the full interview above, and read all the lyrics to Akon’s “Smack That” featuring Eminem on Genius now.']

# %% [markdown]
# # Tokenization

# %% [markdown]
# My data is actually a list of text. I'm going to combine all text into one large string of text to make it easier to work with.

# %%
text = ' '.join(text)
text
# Out:
# "Back in 2006, Akon recruited Eminem for “Smack That,” the first single from his sophomore album, Konvicted. In a recent interview with Hot 97’s Ebro in the Morning, the Senegalese-American singer provided a look into the Detroit rapper’s 9-to-5 recording schedule. “Working with him made me look at the business different because he was the first artist that I worked with that actually treated the business like a real job,” Akon explained. “He comes in at 9 a.m. every day to the studio, takes his lunch break at 1, and is out of there by 5 p.m. It’s like a schedule.” Not anticipating Em’s strict schedule, Akon showed up on the first day at 6 p.m., only to find out that the Shady Records co-founder had already left for the day. After Em told him to arrive at the studio at 9 a.m. the next day, Akon recalled how Em immediately paused working not only for lunch, but at the end of the day as well. “I’m in the middle of writing a record, and he’s like, ‘Yo, I’m about to go out for lunch,’” Akon remembered. “He goes, takes his lunch [for] an hour, come back. He’s back, ‘What we got?’ I play him the record, play him the chorus, he’s like, ‘This is it. Boom.’ He goes into his verse. 5 o'clock come, he’s halfway in. He’s like, ‘Alright, bro. I'ma see you tomorrow.’” When Em returned the next day to wrap up his verse, Akon naturally asked the legendary MC about his unorthodox approach to recording. According to Akon, Em responded: Nah, man. I just like to be here. I treat it like a real job. I don’t make it no more than what it’s supposed to be. I don’t allow it to stress me out, stay longer than I have to. I got a family, I got a daughter I wanna be spending time with her. I wanna make time. Hearing Em’s explanation resonated with Akon, who has now adjusted his perspective on studio time. “I’m sitting there like, ‘That makes a lot sense. Ain’t nothing gonna change between today and tomorrow,’” said Akon. “I hit him up, I said, ‘You just gave me a whole new outlook on how to treat the business from the creative end of it.’ ‘Cause now I create the schedule going in and I do it when time permits for it, but I don’t force it no more like I used to.”  “Smack That” became one of Akon’s four Top 10 hits from Konvicted. The collaboration peaked at No. 2 on the Billboard Hot 100, making it Eminem’s highest-charting featured appearance. The track was later certified double Platinum in December 2007. Watch the full interview above, and read all the lyrics to Akon’s “Smack That” featuring Eminem on Genius now."

# %%
# Make all text lowercase
text_lowered = text.lower()
text_lowered
# Out:
# "back in 2006, akon recruited eminem for “smack that,” the first single from his sophomore album, konvicted. in a recent interview with hot 97’s ebro in the morning, the senegalese-american singer provided a look into the detroit rapper’s 9-to-5 recording schedule. “working with him made me look at the business different because he was the first artist that i worked with that actually treated the business like a real job,” akon explained. “he comes in at 9 a.m. every day to the studio, takes his lunch break at 1, and is out of there by 5 p.m. it’s like a schedule.” not anticipating em’s strict schedule, akon showed up on the first day at 6 p.m., only to find out that the shady records co-founder had already left for the day. after em told him to arrive at the studio at 9 a.m. the next day, akon recalled how em immediately paused working not only for lunch, but at the end of the day as well. “i’m in the middle of writing a record, and he’s like, ‘yo, i’m about to go out for lunch,’” akon remembered. “he goes, takes his lunch [for] an hour, come back. he’s back, ‘what we got?’ i play him the record, play him the chorus, he’s like, ‘this is it. boom.’ he goes into his verse. 5 o'clock come, he’s halfway in. he’s like, ‘alright, bro. i'ma see you tomorrow.’” when em returned the next day to wrap up his verse, akon naturally asked the legendary mc about his unorthodox approach to recording. according to akon, em responded: nah, man. i just like to be here. i treat it like a real job. i don’t make it no more than what it’s supposed to be. i don’t allow it to stress me out, stay longer than i have to. i got a family, i got a daughter i wanna be spending time with her. i wanna make time. hearing em’s explanation resonated with akon, who has now adjusted his perspective on studio time. “i’m sitting there like, ‘that makes a lot sense. ain’t nothing gonna change between today and tomorrow,’” said akon. “i hit him up, i said, ‘you just gave me a whole new outlook on how to treat the business from the creative end of it.’ ‘cause now i create the schedule going in and i do it when time permits for it, but i don’t force it no more like i used to.”  “smack that” became one of akon’s four top 10 hits from konvicted. the collaboration peaked at no. 2 on the billboard hot 100, making it eminem’s highest-charting featured appearance. the track was later certified double platinum in december 2007. watch the full interview above, and read all the lyrics to akon’s “smack that” featuring eminem on genius now."

# %%
from nltk.tokenize import word_tokenize
# Tokenize the lowercase text
word_tokens = word_tokenize(text_lowered) 
word_tokens
# Out:
# ['back',
#  'in',
#  '2006',
#  ',',
#  'akon',
#  'recruited',
#  'eminem',
#  'for',
#  '“',
#  'smack',
#  'that',
#  ',',
#  '”',
#  'the',
#  'first',
#  'single',
#  'from',
#  'his',
#  'sophomore',
#  'album',
#  ',',
#  'konvicted',
#  '.',
#  'in',
#  'a',
#  'recent',
#  'interview',
#  'with',
#  'hot',
#  '97',
#  '’',
#  's',
#  'ebro',
#  'in',
#  'the',
#  'morning',
#  ',',
#  'the',
#  'senegalese-american',
#  'singer',
#  'provided',
#  'a',
#  'look',
#  'into',
#  'the',
#  'detroit',
#  'rapper',
#  '’',
#  's',
#  '9-to-5',
#  'recording',
#  'schedule',
#  '.',
#  '“',
#  'working',
#  'with',
#  'him',
#  'made',
#  'me',
#  'look',
#  'at',
#  'the',
#  'business',
#  'different',
#  'because',
#  'he',
#  'was',
#  'the',
#  'first',
#  'artist',
#  'that',
#  'i',
#  'worked',
#  'with',
#  'that',
#  'actually',
#  'treated',
#  'the',
#  'business',
#  'like',
#  'a',
#  'real',
#  'job',
#  ',',
#  '”',
#  'akon',
#  'explained',
#  '.',
#  '“',
#  'he',
#  'comes',
#  'in',
#  'at',
#  '9',
#  'a.m.',
#  'every',
#  'day',
#  'to',
#  'the',
#  'studio',
#  ',',
#  'takes',
#  'his',
#  'lunch',
#  'break',
#  'at',
#  '1',
#  ',',
#  'and',
#  'is',
#  'out',
#  'of',
#  'there',
#  'by',
#  '5',
#  'p.m.',
#  'it',
#  '’',
#  's',
#  'like',
#  'a',
#  'schedule.',
#  '”',
#  'not',
#  'anticipating',
#  'em',
#  '’',
#  's',
#  'strict',
#  'schedule',
#  ',',
#  'akon',
#  'showed',
#  'up',
#  'on',
#  'the',
#  'first',
#  'day',
#  'at',
#  '6',
#  'p.m.',
#  ',',
#  'only',
#  'to',
#  'find',
#  'out',
#  'that',
#  'the',
#  'shady',
#  'records',
#  'co-founder',
#  'had',
#  'already',
#  'left',
#  'for',
#  'the',
#  'day',
#  '.',
#  'after',
#  'em',
#  'told',
#  'him',
#  'to',
#  'arrive',
#  'at',
#  'the',
#  'studio',
#  'at',
#  '9',
#  'a.m.',
#  'the',
#  'next',
#  'day',
#  ',',
#  'akon',
#  'recalled',
#  'how',
#  'em',
#  'immediately',
#  'paused',
#  'working',
#  'not',
#  'only',
#  'for',
#  'lunch',
#  ',',
#  'but',
#  'at',
#  'the',
#  'end',
#  'of',
#  'the',
#  'day',
#  'as',
#  'well',
#  '.',
#  '“',
#  'i',
#  '’',
#  'm',
#  'in',
#  'the',
#  'middle',
#  'of',
#  'writing',
#  'a',
#  'record',
#  ',',
#  'and',
#  'he',
#  '’',
#  's',
#  'like',
#  ',',
#  '‘',
#  'yo',
#  ',',
#  'i',
#  '’',
#  'm',
#  'about',
#  'to',
#  'go',
#  'out',
#  'for',
#  'lunch',
#  ',',
#  '’',
#  '”',
#  'akon',
#  'remembered',
#  '.',
#  '“',
#  'he',
#  'goes',
#  ',',
#  'takes',
#  'his',
#  'lunch',
#  '[',
#  'for',
#  ']',
#  'an',
#  'hour',
#  ',',
#  'come',
#  'back',
#  '.',
#  'he',
#  '’',
#  's',
#  'back',
#  ',',
#  '‘',
#  'what',
#  'we',
#  'got',
#  '?',
#  '’',
#  'i',
#  'play',
#  'him',
#  'the',
#  'record',
#  ',',
#  'play',
#  'him',
#  'the',
#  'chorus',
#  ',',
#  'he',
#  '’',
#  's',
#  'like',
#  ',',
#  '‘',
#  'this',
#  'is',
#  'it',
#  '.',
#  'boom.',
#  '’',
#  'he',
#  'goes',
#  'into',
#  'his',
#  'verse',
#  '.',
#  '5',
#  "o'clock",
#  'come',
#  ',',
#  'he',
#  '’',
#  's',
#  'halfway',
#  'in',
#  '.',
#  'he',
#  '’',
#  's',
#  'like',
#  ',',
#  '‘',
#  'alright',
#  ',',
#  'bro',
#  '.',
#  "i'ma",
#  'see',
#  'you',
#  'tomorrow.',
#  '’',
#  '”',
#  'when',
#  'em',
#  'returned',
#  'the',
#  'next',
#  'day',
#  'to',
#  'wrap',
#  'up',
#  'his',
#  'verse',
#  ',',
#  'akon',
#  'naturally',
#  'asked',
#  'the',
#  'legendary',
#  'mc',
#  'about',
#  'his',
#  'unorthodox',
#  'approach',
#  'to',
#  'recording',
#  '.',
#  'according',
#  'to',
#  'akon',
#  ',',
#  'em',
#  'responded',
#  ':',
#  'nah',
#  ',',
#  'man',
#  '.',
#  'i',
#  'just',
#  'like',
#  'to',
#  'be',
#  'here',
#  '.',
#  'i',
#  'treat',
#  'it',
#  'like',
#  'a',
#  'real',
#  'job',
#  '.',
#  'i',
#  'don',
#  '’',
#  't',
#  'make',
#  'it',
#  'no',
#  'more',
#  'than',
#  'what',
#  'it',
#  '’',
#  's',
#  'supposed',
#  'to',
#  'be',
#  '.',
#  'i',
#  'don',
#  '’',
#  't',
#  'allow',
#  'it',
#  'to',
#  'stress',
#  'me',
#  'out',
#  ',',
#  'stay',
#  'longer',
#  'than',
#  'i',
#  'have',
#  'to',
#  '.',
#  'i',
#  'got',
#  'a',
#  'family',
#  ',',
#  'i',
#  'got',
#  'a',
#  'daughter',
#  'i',
#  'wan',
#  'na',
#  'be',
#  'spending',
#  'time',
#  'with',
#  'her',
#  '.',
#  'i',
#  'wan',
#  'na',
#  'make',
#  'time',
#  '.',
#  'hearing',
#  'em',
#  '’',
#  's',
#  'explanation',
#  'resonated',
#  'with',
#  'akon',
#  ',',
#  'who',
#  'has',
#  'now',
#  'adjusted',
#  'his',
#  'perspective',
#  'on',
#  'studio',
#  'time',
#  '.',
#  '“',
#  'i',
#  '’',
#  'm',
#  'sitting',
#  'there',
#  'like',
#  ',',
#  '‘',
#  'that',
#  'makes',
#  'a',
#  'lot',
#  'sense',
#  '.',
#  'ain',
#  '’',
#  't',
#  'nothing',
#  'gon',
#  'na',
#  'change',
#  'between',
#  'today',
#  'and',
#  'tomorrow',
#  ',',
#  '’',
#  '”',
#  'said',
#  'akon',
#  '.',
#  '“',
#  'i',
#  'hit',
#  'him',
#  'up',
#  ',',
#  'i',
#  'said',
#  ',',
#  '‘',
#  'you',
#  'just',
#  'gave',
#  'me',
#  'a',
#  'whole',
#  'new',
#  'outlook',
#  'on',
#  'how',
#  'to',
#  'treat',
#  'the',
#  'business',
#  'from',
#  'the',
#  'creative',
#  'end',
#  'of',
#  'it.',
#  '’',
#  '‘',
#  'cause',
#  'now',
#  'i',
#  'create',
#  'the',
#  'schedule',
#  'going',
#  'in',
#  'and',
#  'i',
#  'do',
#  'it',
#  'when',
#  'time',
#  'permits',
#  'for',
#  'it',
#  ',',
#  'but',
#  'i',
#  'don',
#  '’',
#  't',
#  'force',
#  'it',
#  'no',
#  'more',
#  'like',
#  'i',
#  'used',
#  'to.',
#  '”',
#  '“',
#  'smack',
#  'that',
#  '”',
#  'became',
#  'one',
#  'of',
#  'akon',
#  '’',
#  's',
#  'four',
#  'top',
#  '10',
#  'hits',
#  'from',
#  'konvicted',
#  '.',
#  'the',
#  'collaboration',
#  'peaked',
#  'at',
#  'no',
#  '.',
#  '2',
#  'on',
#  'the',
#  'billboard',
#  'hot',
#  '100',
#  ',',
#  'making',
#  'it',
#  'eminem',
#  '’',
#  's',
#  'highest-charting',
#  'featured',
#  'appearance',
#  '.',
#  'the',
#  'track',
#  'was',
#  'later',
#  'certified',
#  'double',
#  'platinum',
#  'in',
#  'december',
#  '2007.',
#  'watch',
#  'the',
#  'full',
#  'interview',
#  'above',
#  ',',
#  'and',
#  'read',
#  'all',
#  'the',
#  'lyrics',
#  'to',
#  'akon',
#  '’',
#  's',
#  '“',
#  'smack',
#  'that',
#  '”',
#  'featuring',
#  'eminem',
#  'on',
#  'genius',
#  'now',
#  '.']

# %% [markdown]
# ## Removing Stop Words

# %%
from nltk.corpus import stopwords

filtered_words = [word for word in word_tokens if word not in stopwords.words('english')]
filtered_words
# Out:
# ['back',
#  '2006',
#  ',',
#  'akon',
#  'recruited',
#  'eminem',
#  '“',
#  'smack',
#  ',',
#  '”',
#  'first',
#  'single',
#  'sophomore',
#  'album',
#  ',',
#  'konvicted',
#  '.',
#  'recent',
#  'interview',
#  'hot',
#  '97',
#  '’',
#  'ebro',
#  'morning',
#  ',',
#  'senegalese-american',
#  'singer',
#  'provided',
#  'look',
#  'detroit',
#  'rapper',
#  '’',
#  '9-to-5',
#  'recording',
#  'schedule',
#  '.',
#  '“',
#  'working',
#  'made',
#  'look',
#  'business',
#  'different',
#  'first',
#  'artist',
#  'worked',
#  'actually',
#  'treated',
#  'business',
#  'like',
#  'real',
#  'job',
#  ',',
#  '”',
#  'akon',
#  'explained',
#  '.',
#  '“',
#  'comes',
#  '9',
#  'a.m.',
#  'every',
#  'day',
#  'studio',
#  ',',
#  'takes',
#  'lunch',
#  'break',
#  '1',
#  ',',
#  '5',
#  'p.m.',
#  '’',
#  'like',
#  'schedule.',
#  '”',
#  'anticipating',
#  'em',
#  '’',
#  'strict',
#  'schedule',
#  ',',
#  'akon',
#  'showed',
#  'first',
#  'day',
#  '6',
#  'p.m.',
#  ',',
#  'find',
#  'shady',
#  'records',
#  'co-founder',
#  'already',
#  'left',
#  'day',
#  '.',
#  'em',
#  'told',
#  'arrive',
#  'studio',
#  '9',
#  'a.m.',
#  'next',
#  'day',
#  ',',
#  'akon',
#  'recalled',
#  'em',
#  'immediately',
#  'paused',
#  'working',
#  'lunch',
#  ',',
#  'end',
#  'day',
#  'well',
#  '.',
#  '“',
#  '’',
#  'middle',
#  'writing',
#  'record',
#  ',',
#  '’',
#  'like',
#  ',',
#  '‘',
#  'yo',
#  ',',
#  '’',
#  'go',
#  'lunch',
#  ',',
#  '’',
#  '”',
#  'akon',
#  'remembered',
#  '.',
#  '“',
#  'goes',
#  ',',
#  'takes',
#  'lunch',
#  '[',
#  ']',
#  'hour',
#  ',',
#  'come',
#  'back',
#  '.',
#  '’',
#  'back',
#  ',',
#  '‘',
#  'got',
#  '?',
#  '’',
#  'play',
#  'record',
#  ',',
#  'play',
#  'chorus',
#  ',',
#  '’',
#  'like',
#  ',',
#  '‘',
#  '.',
#  'boom.',
#  '’',
#  'goes',
#  'verse',
#  '.',
#  '5',
#  "o'clock",
#  'come',
#  ',',
#  '’',
#  'halfway',
#  '.',
#  '’',
#  'like',
#  ',',
#  '‘',
#  'alright',
#  ',',
#  'bro',
#  '.',
#  "i'ma",
#  'see',
#  'tomorrow.',
#  '’',
#  '”',
#  'em',
#  'returned',
#  'next',
#  'day',
#  'wrap',
#  'verse',
#  ',',
#  'akon',
#  'naturally',
#  'asked',
#  'legendary',
#  'mc',
#  'unorthodox',
#  'approach',
#  'recording',
#  '.',
#  'according',
#  'akon',
#  ',',
#  'em',
#  'responded',
#  ':',
#  'nah',
#  ',',
#  'man',
#  '.',
#  'like',
#  '.',
#  'treat',
#  'like',
#  'real',
#  'job',
#  '.',
#  '’',
#  'make',
#  '’',
#  'supposed',
#  '.',
#  '’',
#  'allow',
#  'stress',
#  ',',
#  'stay',
#  'longer',
#  '.',
#  'got',
#  'family',
#  ',',
#  'got',
#  'daughter',
#  'wan',
#  'na',
#  'spending',
#  'time',
#  '.',
#  'wan',
#  'na',
#  'make',
#  'time',
#  '.',
#  'hearing',
#  'em',
#  '’',
#  'explanation',
#  'resonated',
#  'akon',
#  ',',
#  'adjusted',
#  'perspective',
#  'studio',
#  'time',
#  '.',
#  '“',
#  '’',
#  'sitting',
#  'like',
#  ',',
#  '‘',
#  'makes',
#  'lot',
#  'sense',
#  '.',
#  '’',
#  'nothing',
#  'gon',
#  'na',
#  'change',
#  'today',
#  'tomorrow',
#  ',',
#  '’',
#  '”',
#  'said',
#  'akon',
#  '.',
#  '“',
#  'hit',
#  ',',
#  'said',
#  ',',
#  '‘',
#  'gave',
#  'whole',
#  'new',
#  'outlook',
#  'treat',
#  'business',
#  'creative',
#  'end',
#  'it.',
#  '’',
#  '‘',
#  'cause',
#  'create',
#  'schedule',
#  'going',
#  'time',
#  'permits',
#  ',',
#  '’',
#  'force',
#  'like',
#  'used',
#  'to.',
#  '”',
#  '“',
#  'smack',
#  '”',
#  'became',
#  'one',
#  'akon',
#  '’',
#  'four',
#  'top',
#  '10',
#  'hits',
#  'konvicted',
#  '.',
#  'collaboration',
#  'peaked',
#  '.',
#  '2',
#  'billboard',
#  'hot',
#  '100',
#  ',',
#  'making',
#  'eminem',
#  '’',
#  'highest-charting',
#  'featured',
#  'appearance',
#  '.',
#  'track',
#  'later',
#  'certified',
#  'double',
#  'platinum',
#  'december',
#  '2007.',
#  'watch',
#  'full',
#  'interview',
#  ',',
#  'read',
#  'lyrics',
#  'akon',
#  '’',
#  '“',
#  'smack',
#  '”',
#  'featuring',
#  'eminem',
#  'genius',
#  '.']

# %% [markdown]
# ## Stemming
# I'll use the Porter stemmer.

# %%
from nltk.stem import PorterStemmer

porter = PorterStemmer()
stemmed_words = [porter.stem(w) for w in filtered_words]
stemmed_words
# Out:
# ['back',
#  '2006',
#  ',',
#  'akon',
#  'recruit',
#  'eminem',
#  '“',
#  'smack',
#  ',',
#  '”',
#  'first',
#  'singl',
#  'sophomor',
#  'album',
#  ',',
#  'konvict',
#  '.',
#  'recent',
#  'interview',
#  'hot',
#  '97',
#  '’',
#  'ebro',
#  'morn',
#  ',',
#  'senegalese-american',
#  'singer',
#  'provid',
#  'look',
#  'detroit',
#  'rapper',
#  '’',
#  '9-to-5',
#  'record',
#  'schedul',
#  '.',
#  '“',
#  'work',
#  'made',
#  'look',
#  'busi',
#  'differ',
#  'first',
#  'artist',
#  'work',
#  'actual',
#  'treat',
#  'busi',
#  'like',
#  'real',
#  'job',
#  ',',
#  '”',
#  'akon',
#  'explain',
#  '.',
#  '“',
#  'come',
#  '9',
#  'a.m.',
#  'everi',
#  'day',
#  'studio',
#  ',',
#  'take',
#  'lunch',
#  'break',
#  '1',
#  ',',
#  '5',
#  'p.m.',
#  '’',
#  'like',
#  'schedule.',
#  '”',
#  'anticip',
#  'em',
#  '’',
#  'strict',
#  'schedul',
#  ',',
#  'akon',
#  'show',
#  'first',
#  'day',
#  '6',
#  'p.m.',
#  ',',
#  'find',
#  'shadi',
#  'record',
#  'co-found',
#  'alreadi',
#  'left',
#  'day',
#  '.',
#  'em',
#  'told',
#  'arriv',
#  'studio',
#  '9',
#  'a.m.',
#  'next',
#  'day',
#  ',',
#  'akon',
#  'recal',
#  'em',
#  'immedi',
#  'paus',
#  'work',
#  'lunch',
#  ',',
#  'end',
#  'day',
#  'well',
#  '.',
#  '“',
#  '’',
#  'middl',
#  'write',
#  'record',
#  ',',
#  '’',
#  'like',
#  ',',
#  '‘',
#  'yo',
#  ',',
#  '’',
#  'go',
#  'lunch',
#  ',',
#  '’',
#  '”',
#  'akon',
#  'rememb',
#  '.',
#  '“',
#  'goe',
#  ',',
#  'take',
#  'lunch',
#  '[',
#  ']',
#  'hour',
#  ',',
#  'come',
#  'back',
#  '.',
#  '’',
#  'back',
#  ',',
#  '‘',
#  'got',
#  '?',
#  '’',
#  'play',
#  'record',
#  ',',
#  'play',
#  'choru',
#  ',',
#  '’',
#  'like',
#  ',',
#  '‘',
#  '.',
#  'boom.',
#  '’',
#  'goe',
#  'vers',
#  '.',
#  '5',
#  "o'clock",
#  'come',
#  ',',
#  '’',
#  'halfway',
#  '.',
#  '’',
#  'like',
#  ',',
#  '‘',
#  'alright',
#  ',',
#  'bro',
#  '.',
#  "i'ma",
#  'see',
#  'tomorrow.',
#  '’',
#  '”',
#  'em',
#  'return',
#  'next',
#  'day',
#  'wrap',
#  'vers',
#  ',',
#  'akon',
#  'natur',
#  'ask',
#  'legendari',
#  'mc',
#  'unorthodox',
#  'approach',
#  'record',
#  '.',
#  'accord',
#  'akon',
#  ',',
#  'em',
#  'respond',
#  ':',
#  'nah',
#  ',',
#  'man',
#  '.',
#  'like',
#  '.',
#  'treat',
#  'like',
#  'real',
#  'job',
#  '.',
#  '’',
#  'make',
#  '’',
#  'suppos',
#  '.',
#  '’',
#  'allow',
#  'stress',
#  ',',
#  'stay',
#  'longer',
#  '.',
#  'got',
#  'famili',
#  ',',
#  'got',
#  'daughter',
#  'wan',
#  'na',
#  'spend',
#  'time',
#  '.',
#  'wan',
#  'na',
#  'make',
#  'time',
#  '.',
#  'hear',
#  'em',
#  '’',
#  'explan',
#  'reson',
#  'akon',
#  ',',
#  'adjust',
#  'perspect',
#  'studio',
#  'time',
#  '.',
#  '“',
#  '’',
#  'sit',
#  'like',
#  ',',
#  '‘',
#  'make',
#  'lot',
#  'sens',
#  '.',
#  '’',
#  'noth',
#  'gon',
#  'na',
#  'chang',
#  'today',
#  'tomorrow',
#  ',',
#  '’',
#  '”',
#  'said',
#  'akon',
#  '.',
#  '“',
#  'hit',
#  ',',
#  'said',
#  ',',
#  '‘',
#  'gave',
#  'whole',
#  'new',
#  'outlook',
#  'treat',
#  'busi',
#  'creativ',
#  'end',
#  'it.',
#  '’',
#  '‘',
#  'caus',
#  'creat',
#  'schedul',
#  'go',
#  'time',
#  'permit',
#  ',',
#  '’',
#  'forc',
#  'like',
#  'use',
#  'to.',
#  '”',
#  '“',
#  'smack',
#  '”',
#  'becam',
#  'one',
#  'akon',
#  '’',
#  'four',
#  'top',
#  '10',
#  'hit',
#  'konvict',
#  '.',
#  'collabor',
#  'peak',
#  '.',
#  '2',
#  'billboard',
#  'hot',
#  '100',
#  ',',
#  'make',
#  'eminem',
#  '’',
#  'highest-chart',
#  'featur',
#  'appear',
#  '.',
#  'track',
#  'later',
#  'certifi',
#  'doubl',
#  'platinum',
#  'decemb',
#  '2007.',
#  'watch',
#  'full',
#  'interview',
#  ',',
#  'read',
#  'lyric',
#  'akon',
#  '’',
#  '“',
#  'smack',
#  '”',
#  'featur',
#  'eminem',
#  'geniu',
#  '.']

# %% [markdown]
# **For an easier side-by-side visual comparison I will combine the original filtered words and the stemmed filtered words into a dictionary.**
#
# Notice, for example, that words like `single` became `singl` and `sophomore` became `sophomor`.

# %%
dict(zip(filtered_words, stemmed_words))
# Out:
# {'back': 'back',
#  '2006': '2006',
#  ',': ',',
#  'akon': 'akon',
#  'recruited': 'recruit',
#  'eminem': 'eminem',
#  '“': '“',
#  'smack': 'smack',
#  '”': '”',
#  'first': 'first',
#  'single': 'singl',
#  'sophomore': 'sophomor',
#  'album': 'album',
#  'konvicted': 'konvict',
#  '.': '.',
#  'recent': 'recent',
#  'interview': 'interview',
#  'hot': 'hot',
#  '97': '97',
#  '’': '’',
#  'ebro': 'ebro',
#  'morning': 'morn',
#  'senegalese-american': 'senegalese-american',
#  'singer': 'singer',
#  'provided': 'provid',
#  'look': 'look',
#  'detroit': 'detroit',
#  'rapper': 'rapper',
#  '9-to-5': '9-to-5',
#  'recording': 'record',
#  'schedule': 'schedul',
#  'working': 'work',
#  'made': 'made',
#  'business': 'busi',
#  'different': 'differ',
#  'artist': 'artist',
#  'worked': 'work',
#  'actually': 'actual',
#  'treated': 'treat',
#  'like': 'like',
#  'real': 'real',
#  'job': 'job',
#  'explained': 'explain',
#  'comes': 'come',
#  '9': '9',
#  'a.m.': 'a.m.',
#  'every': 'everi',
#  'day': 'day',
#  'studio': 'studio',
#  'takes': 'take',
#  'lunch': 'lunch',
#  'break': 'break',
#  '1': '1',
#  '5': '5',
#  'p.m.': 'p.m.',
#  'schedule.': 'schedule.',
#  'anticipating': 'anticip',
#  'em': 'em',
#  'strict': 'strict',
#  'showed': 'show',
#  '6': '6',
#  'find': 'find',
#  'shady': 'shadi',
#  'records': 'record',
#  'co-founder': 'co-found',
#  'already': 'alreadi',
#  'left': 'left',
#  'told': 'told',
#  'arrive': 'arriv',
#  'next': 'next',
#  'recalled': 'recal',
#  'immediately': 'immedi',
#  'paused': 'paus',
#  'end': 'end',
#  'well': 'well',
#  'middle': 'middl',
#  'writing': 'write',
#  'record': 'record',
#  '‘': '‘',
#  'yo': 'yo',
#  'go': 'go',
#  'remembered': 'rememb',
#  'goes': 'goe',
#  '[': '[',
#  ']': ']',
#  'hour': 'hour',
#  'come': 'come',
#  'got': 'got',
#  '?': '?',
#  'play': 'play',
#  'chorus': 'choru',
#  'boom.': 'boom.',
#  'verse': 'vers',
#  "o'clock": "o'clock",
#  'halfway': 'halfway',
#  'alright': 'alright',
#  'bro': 'bro',
#  "i'ma": "i'ma",
#  'see': 'see',
#  'tomorrow.': 'tomorrow.',
#  'returned': 'return',
#  'wrap': 'wrap',
#  'naturally': 'natur',
#  'asked': 'ask',
#  'legendary': 'legendari',
#  'mc': 'mc',
#  'unorthodox': 'unorthodox',
#  'approach': 'approach',
#  'according': 'accord',
#  'responded': 'respond',
#  ':': ':',
#  'nah': 'nah',
#  'man': 'man',
#  'treat': 'treat',
#  'make': 'make',
#  'supposed': 'suppos',
#  'allow': 'allow',
#  'stress': 'stress',
#  'stay': 'stay',
#  'longer': 'longer',
#  'family': 'famili',
#  'daughter': 'daughter',
#  'wan': 'wan',
#  'na': 'na',
#  'spending': 'spend',
#  'time': 'time',
#  'hearing': 'hear',
#  'explanation': 'explan',
#  'resonated': 'reson',
#  'adjusted': 'adjust',
#  'perspective': 'perspect',
#  'sitting': 'sit',
#  'makes': 'make',
#  'lot': 'lot',
#  'sense': 'sens',
#  'nothing': 'noth',
#  'gon': 'gon',
#  'change': 'chang',
#  'today': 'today',
#  'tomorrow': 'tomorrow',
#  'said': 'said',
#  'hit': 'hit',
#  'gave': 'gave',
#  'whole': 'whole',
#  'new': 'new',
#  'outlook': 'outlook',
#  'creative': 'creativ',
#  'it.': 'it.',
#  'cause': 'caus',
#  'create': 'creat',
#  'going': 'go',
#  'permits': 'permit',
#  'force': 'forc',
#  'used': 'use',
#  'to.': 'to.',
#  'became': 'becam',
#  'one': 'one',
#  'four': 'four',
#  'top': 'top',
#  '10': '10',
#  'hits': 'hit',
#  'collaboration': 'collabor',
#  'peaked': 'peak',
#  '2': '2',
#  'billboard': 'billboard',
#  '100': '100',
#  'making': 'make',
#  'highest-charting': 'highest-chart',
#  'featured': 'featur',
#  'appearance': 'appear',
#  'track': 'track',
#  'later': 'later',
#  'certified': 'certifi',
#  'double': 'doubl',
#  'platinum': 'platinum',
#  'december': 'decemb',
#  '2007.': '2007.',
#  'watch': 'watch',
#  'full': 'full',
#  'read': 'read',
#  'lyrics': 'lyric',
#  'featuring': 'featur',
#  'genius': 'geniu'}

# %% [markdown]
# ## Lemmatization

# %%
from nltk import pos_tag

tagged_words = pos_tag(filtered_words)
tagged_words
# Out:
# [('back', 'RB'),
#  ('2006', 'CD'),
#  (',', ','),
#  ('akon', 'RB'),
#  ('recruited', 'VBN'),
#  ('eminem', 'NN'),
#  ('“', 'NNP'),
#  ('smack', 'NN'),
#  (',', ','),
#  ('”', 'NNP'),
#  ('first', 'RB'),
#  ('single', 'JJ'),
#  ('sophomore', 'NN'),
#  ('album', 'NN'),
#  (',', ','),
#  ('konvicted', 'VBN'),
#  ('.', '.'),
#  ('recent', 'JJ'),
#  ('interview', 'NN'),
#  ('hot', 'JJ'),
#  ('97', 'CD'),
#  ('’', 'JJ'),
#  ('ebro', 'NN'),
#  ('morning', 'NN'),
#  (',', ','),
#  ('senegalese-american', 'JJ'),
#  ('singer', 'NN'),
#  ('provided', 'VBD'),
#  ('look', 'NN'),
#  ('detroit', 'JJ'),
#  ('rapper', 'NN'),
#  ('’', 'NNP'),
#  ('9-to-5', 'CD'),
#  ('recording', 'NN'),
#  ('schedule', 'NN'),
#  ('.', '.'),
#  ('“', 'NN'),
#  ('working', 'VBG'),
#  ('made', 'VBN'),
#  ('look', 'NN'),
#  ('business', 'NN'),
#  ('different', 'JJ'),
#  ('first', 'JJ'),
#  ('artist', 'NN'),
#  ('worked', 'VBD'),
#  ('actually', 'RB'),
#  ('treated', 'JJ'),
#  ('business', 'NN'),
#  ('like', 'IN'),
#  ('real', 'JJ'),
#  ('job', 'NN'),
#  (',', ','),
#  ('”', 'NNP'),
#  ('akon', 'NN'),
#  ('explained', 'VBD'),
#  ('.', '.'),
#  ('“', 'NN'),
#  ('comes', 'VBZ'),
#  ('9', 'CD'),
#  ('a.m.', 'NN'),
#  ('every', 'DT'),
#  ('day', 'NN'),
#  ('studio', 'NN'),
#  (',', ','),
#  ('takes', 'VBZ'),
#  ('lunch', 'JJ'),
#  ('break', 'NN'),
#  ('1', 'CD'),
#  (',', ','),
#  ('5', 'CD'),
#  ('p.m.', 'NN'),
#  ('’', 'NNP'),
#  ('like', 'IN'),
#  ('schedule.', 'NN'),
#  ('”', 'NNP'),
#  ('anticipating', 'VBG'),
#  ('em', 'JJ'),
#  ('’', 'NNP'),
#  ('strict', 'NN'),
#  ('schedule', 'NN'),
#  (',', ','),
#  ('akon', 'NN'),
#  ('showed', 'VBD'),
#  ('first', 'JJ'),
#  ('day', 'NN'),
#  ('6', 'CD'),
#  ('p.m.', 'NN'),
#  (',', ','),
#  ('find', 'VBP'),
#  ('shady', 'JJ'),
#  ('records', 'NNS'),
#  ('co-founder', 'NN'),
#  ('already', 'RB'),
#  ('left', 'VBD'),
#  ('day', 'NN'),
#  ('.', '.'),
#  ('em', 'CC'),
#  ('told', 'VBD'),
#  ('arrive', 'JJ'),
#  ('studio', 'NN'),
#  ('9', 'CD'),
#  ('a.m.', 'NN'),
#  ('next', 'JJ'),
#  ('day', 'NN'),
#  (',', ','),
#  ('akon', 'NN'),
#  ('recalled', 'VBD'),
#  ('em', 'RB'),
#  ('immediately', 'RB'),
#  ('paused', 'JJ'),
#  ('working', 'VBG'),
#  ('lunch', 'NN'),
#  (',', ','),
#  ('end', 'NN'),
#  ('day', 'NN'),
#  ('well', 'RB'),
#  ('.', '.'),
#  ('“', 'VB'),
#  ('’', 'JJ'),
#  ('middle', 'JJ'),
#  ('writing', 'NN'),
#  ('record', 'NN'),
#  (',', ','),
#  ('’', 'NNP'),
#  ('like', 'IN'),
#  (',', ','),
#  ('‘', 'NNP'),
#  ('yo', 'NNP'),
#  (',', ','),
#  ('’', 'NNP'),
#  ('go', 'VBP'),
#  ('lunch', 'NN'),
#  (',', ','),
#  ('’', 'NNP'),
#  ('”', 'NNP'),
#  ('akon', 'NN'),
#  ('remembered', 'VBD'),
#  ('.', '.'),
#  ('“', 'NN'),
#  ('goes', 'VBZ'),
#  (',', ','),
#  ('takes', 'VBZ'),
#  ('lunch', 'NN'),
#  ('[', 'NNP'),
#  (']', 'NNP'),
#  ('hour', 'NN'),
#  (',', ','),
#  ('come', 'VB'),
#  ('back', 'RB'),
#  ('.', '.'),
#  ('’', 'NN'),
#  ('back', 'RB'),
#  (',', ','),
#  ('‘', 'NNP'),
#  ('got', 'VBD'),
#  ('?', '.'),
#  ('’', 'JJ'),
#  ('play', 'NN'),
#  ('record', 'NN'),
#  (',', ','),
#  ('play', 'VB'),
#  ('chorus', 'NN'),
#  (',', ','),
#  ('’', 'NN'),
#  ('like', 'IN'),
#  (',', ','),
#  ('‘', 'FW'),
#  ('.', '.'),
#  ('boom.', 'NN'),
#  ('’', 'NN'),
#  ('goes', 'VBZ'),
#  ('verse', 'RB'),
#  ('.', '.'),
#  ('5', 'CD'),
#  ("o'clock", 'NN'),
#  ('come', 'NN'),
#  (',', ','),
#  ('’', 'NNP'),
#  ('halfway', 'NN'),
#  ('.', '.'),
#  ('’', 'NN'),
#  ('like', 'IN'),
#  (',', ','),
#  ('‘', 'NNP'),
#  ('alright', 'VBD'),
#  (',', ','),
#  ('bro', 'NN'),
#  ('.', '.'),
#  ("i'ma", 'JJ'),
#  ('see', 'VBP'),
#  ('tomorrow.', 'JJ'),
#  ('’', 'NNP'),
#  ('”', 'NNP'),
#  ('em', 'NN'),
#  ('returned', 'VBD'),
#  ('next', 'JJ'),
#  ('day', 'NN'),
#  ('wrap', 'VBD'),
#  ('verse', 'NN'),
#  (',', ','),
#  ('akon', 'VBP'),
#  ('naturally', 'RB'),
#  ('asked', 'VBN'),
#  ('legendary', 'JJ'),
#  ('mc', 'NN'),
#  ('unorthodox', 'JJ'),
#  ('approach', 'NN'),
#  ('recording', 'NN'),
#  ('.', '.'),
#  ('according', 'VBG'),
#  ('akon', 'NN'),
#  (',', ','),
#  ('em', 'NN'),
#  ('responded', 'VBD'),
#  (':', ':'),
#  ('nah', 'NN'),
#  (',', ','),
#  ('man', 'NN'),
#  ('.', '.'),
#  ('like', 'IN'),
#  ('.', '.'),
#  ('treat', 'NN'),
#  ('like', 'IN'),
#  ('real', 'JJ'),
#  ('job', 'NN'),
#  ('.', '.'),
#  ('’', 'JJ'),
#  ('make', 'VBP'),
#  ('’', 'NN'),
#  ('supposed', 'VBN'),
#  ('.', '.'),
#  ('’', 'VB'),
#  ('allow', 'JJ'),
#  ('stress', 'NN'),
#  (',', ','),
#  ('stay', 'NN'),
#  ('longer', 'RB'),
#  ('.', '.'),
#  ('got', 'VBD'),
#  ('family', 'NN'),
#  (',', ','),
#  ('got', 'VBD'),
#  ('daughter', 'JJ'),
#  ('wan', 'NN'),
#  ('na', 'IN'),
#  ('spending', 'NN'),
#  ('time', 'NN'),
#  ('.', '.'),
#  ('wan', 'VB'),
#  ('na', 'JJ'),
#  ('make', 'NN'),
#  ('time', 'NN'),
#  ('.', '.'),
#  ('hearing', 'VBG'),
#  ('em', 'JJ'),
#  ('’', 'JJ'),
#  ('explanation', 'NN'),
#  ('resonated', 'VBD'),
#  ('akon', 'NNS'),
#  (',', ','),
#  ('adjusted', 'VBN'),
#  ('perspective', 'JJ'),
#  ('studio', 'NN'),
#  ('time', 'NN'),
#  ('.', '.'),
#  ('“', 'VB'),
#  ('’', 'JJ'),
#  ('sitting', 'VBG'),
#  ('like', 'IN'),
#  (',', ','),
#  ('‘', 'NNP'),
#  ('makes', 'VBZ'),
#  ('lot', 'NN'),
#  ('sense', 'NN'),
#  ('.', '.'),
#  ('’', 'VB'),
#  ('nothing', 'NN'),
#  ('gon', 'NN'),
#  ('na', 'TO'),
#  ('change', 'VB'),
#  ('today', 'NN'),
#  ('tomorrow', 'NN'),
#  (',', ','),
#  ('’', 'NNP'),
#  ('”', 'NNP'),
#  ('said', 'VBD'),
#  ('akon', 'NN'),
#  ('.', '.'),
#  ('“', 'NN'),
#  ('hit', 'NN'),
#  (',', ','),
#  ('said', 'VBD'),
#  (',', ','),
#  ('‘', 'NNP'),
#  ('gave', 'VBD'),
#  ('whole', 'JJ'),
#  ('new', 'JJ'),
#  ('outlook', 'NN'),
#  ('treat', 'NN'),
#  ('business', 'NN'),
#  ('creative', 'JJ'),
#  ('end', 'NN'),
#  ('it.', 'NN'),
#  ('’', 'NNP'),
#  ('‘', 'NNP'),
#  ('cause', 'NN'),
#  ('create', 'NN'),
#  ('schedule', 'NN'),
#  ('going', 'VBG'),
#  ('time', 'NN'),
#  ('permits', 'NNS'),
#  (',', ','),
#  ('’', 'NNP'),
#  ('force', 'NN'),
#  ('like', 'IN'),
#  ('used', 'VBN'),
#  ('to.', 'NN'),
#  ('”', 'NNP'),
#  ('“', 'NNP'),
#  ('smack', 'NN'),
#  ('”', 'NN'),
#  ('became', 'VBD'),
#  ('one', 'CD'),
#  ('akon', 'NN'),
#  ('’', 'VBZ'),
#  ('four', 'CD'),
#  ('top', 'NN'),
#  ('10', 'CD'),
#  ('hits', 'NNS'),
#  ('konvicted', 'VBN'),
#  ('.', '.'),
#  ('collaboration', 'NN'),
#  ('peaked', 'VBD'),
#  ('.', '.'),
#  ('2', 'CD'),
#  ('billboard', 'NN'),
#  ('hot', 'JJ'),
#  ('100', 'CD'),
#  (',', ','),
#  ('making', 'VBG'),
#  ('eminem', 'JJ'),
#  ('’', 'JJ'),
#  ('highest-charting', 'NN'),
#  ('featured', 'VBD'),
#  ('appearance', 'NN'),
#  ('.', '.'),
#  ('track', 'NN'),
#  ('later', 'RB'),
#  ('certified', 'VBD'),
#  ('double', 'JJ'),
#  ('platinum', 'NN'),
#  ('december', 'VBD'),
#  ('2007.', 'CD'),
#  ('watch', 'NN'),
#  ('full', 'JJ'),
#  ('interview', 'NN'),
#  (',', ','),
#  ('read', 'VBP'),
#  ('lyrics', 'NNS'),
#  ('akon', 'VBP'),
#  ('’', 'JJ'),
#  ('“', 'NNP'),
#  ('smack', 'NN'),
#  ('”', 'NN'),
#  ('featuring', 'VBG'),
#  ('eminem', 'JJ'),
#  ('genius', 'NN'),
#  ('.', '.')]

# %% [markdown]
# ### Transformation
#
# By default, the WordNetLemmatizer.lemmatize() function will assume that the word is a Noun if there's no explict POS tag in the input. To resolve the problem, always POS-tag your data before lemmatizing.
#
# Above I have a `tagged_words` which is a list of tuples. However, the `.lemmatize()` function takes the word in string format as the first argument and a POS tag in string format as the second argument. So I'll need to create a function that iterate the list of tuples and lemmatizes each word.
#
# Additionally,  because he POS tags used by the part-of-speech tagger are not the same as the POS codes used by WordNet, I need a small mapping function to convert POS tagger tags to WordNet POS codes.
#
# To convert Treebank tags to WordNet tags the mapping is as follows:
# 1. wn.VERB = 'v'
# 2. wn.ADV = 'r'
# 3. wn.NOUN = 'n'
# 4. wn.ADJ = 'a'
# 5. wn.ADJ_SAT = 's'. But we can ignore `'s'` because the `WordNetLemmatizer` in NLTK does not differentiate satellite adjectives from normal adjectives.
#
# From [[WordNet docs](http://www.nltk.org/_modules/nltk/corpus/reader/wordnet.html)]
#
# The other parts of speech will be tagged as nouns. See this [post](https://stackoverflow.com/questions/51634328/wordnetlemmatizer-different-handling-of-wn-adj-and-wn-adj-sat) if you're interested in details.

# %%
tagged_words[0][0]
# Out:
# 'back'

# %%
def convert_tag(treebank_tag):
    '''Convert Treebank tags to WordNet tags'''
    if treebank_tag.startswith('J'):
        return 'a'
    elif treebank_tag.startswith('V'):
        return 'v'
    elif treebank_tag.startswith('N'):
        return 'n'
    elif treebank_tag.startswith('R'):
        return 'r'
    else:
        return 'n' # if no match, default to noun

# %%
from nltk.stem import WordNetLemmatizer # lemmatizes word based on it's parts of speech

# Lemmatize using WordNet's built-in morphy function. Returns the input word unchanged if it cannot be found in WordNet.
wnl = WordNetLemmatizer()

def tuple_lemmatizer(tuple_list):
    '''Lemmatize words leveraging their part-of-speech tags as well'''
    lemma_word = []
    
    for tupl in tuple_list:
        lemma_word.append(wnl.lemmatize(tupl[0], convert_tag(tupl[1])))
    
    return(lemma_word)

# %%
lemma_words = tuple_lemmatizer(tagged_words) # list of lemmatized words

# %%
dict(zip(filtered_words, lemma_words)) # key = original filtered text; value = lemmatized words
# Out:
# {'back': 'back',
#  '2006': '2006',
#  ',': ',',
#  'akon': 'akon',
#  'recruited': 'recruit',
#  'eminem': 'eminem',
#  '“': '“',
#  'smack': 'smack',
#  '”': '”',
#  'first': 'first',
#  'single': 'single',
#  'sophomore': 'sophomore',
#  'album': 'album',
#  'konvicted': 'konvicted',
#  '.': '.',
#  'recent': 'recent',
#  'interview': 'interview',
#  'hot': 'hot',
#  '97': '97',
#  '’': '’',
#  'ebro': 'ebro',
#  'morning': 'morning',
#  'senegalese-american': 'senegalese-american',
#  'singer': 'singer',
#  'provided': 'provide',
#  'look': 'look',
#  'detroit': 'detroit',
#  'rapper': 'rapper',
#  '9-to-5': '9-to-5',
#  'recording': 'recording',
#  'schedule': 'schedule',
#  'working': 'work',
#  'made': 'make',
#  'business': 'business',
#  'different': 'different',
#  'artist': 'artist',
#  'worked': 'work',
#  'actually': 'actually',
#  'treated': 'treated',
#  'like': 'like',
#  'real': 'real',
#  'job': 'job',
#  'explained': 'explain',
#  'comes': 'come',
#  '9': '9',
#  'a.m.': 'a.m.',
#  'every': 'every',
#  'day': 'day',
#  'studio': 'studio',
#  'takes': 'take',
#  'lunch': 'lunch',
#  'break': 'break',
#  '1': '1',
#  '5': '5',
#  'p.m.': 'p.m.',
#  'schedule.': 'schedule.',
#  'anticipating': 'anticipate',
#  'em': 'em',
#  'strict': 'strict',
#  'showed': 'show',
#  '6': '6',
#  'find': 'find',
#  'shady': 'shady',
#  'records': 'record',
#  'co-founder': 'co-founder',
#  'already': 'already',
#  'left': 'leave',
#  'told': 'tell',
#  'arrive': 'arrive',
#  'next': 'next',
#  'recalled': 'recall',
#  'immediately': 'immediately',
#  'paused': 'paused',
#  'end': 'end',
#  'well': 'well',
#  'middle': 'middle',
#  'writing': 'writing',
#  'record': 'record',
#  '‘': '‘',
#  'yo': 'yo',
#  'go': 'go',
#  'remembered': 'remember',
#  'goes': 'go',
#  '[': '[',
#  ']': ']',
#  'hour': 'hour',
#  'come': 'come',
#  'got': 'get',
#  '?': '?',
#  'play': 'play',
#  'chorus': 'chorus',
#  'boom.': 'boom.',
#  'verse': 'verse',
#  "o'clock": "o'clock",
#  'halfway': 'halfway',
#  'alright': 'alright',
#  'bro': 'bro',
#  "i'ma": "i'ma",
#  'see': 'see',
#  'tomorrow.': 'tomorrow.',
#  'returned': 'return',
#  'wrap': 'wrap',
#  'naturally': 'naturally',
#  'asked': 'ask',
#  'legendary': 'legendary',
#  'mc': 'mc',
#  'unorthodox': 'unorthodox',
#  'approach': 'approach',
#  'according': 'accord',
#  'responded': 'respond',
#  ':': ':',
#  'nah': 'nah',
#  'man': 'man',
#  'treat': 'treat',
#  'make': 'make',
#  'supposed': 'suppose',
#  'allow': 'allow',
#  'stress': 'stress',
#  'stay': 'stay',
#  'longer': 'longer',
#  'family': 'family',
#  'daughter': 'daughter',
#  'wan': 'wan',
#  'na': 'na',
#  'spending': 'spending',
#  'time': 'time',
#  'hearing': 'hear',
#  'explanation': 'explanation',
#  'resonated': 'resonate',
#  'adjusted': 'adjust',
#  'perspective': 'perspective',
#  'sitting': 'sit',
#  'makes': 'make',
#  'lot': 'lot',
#  'sense': 'sense',
#  'nothing': 'nothing',
#  'gon': 'gon',
#  'change': 'change',
#  'today': 'today',
#  'tomorrow': 'tomorrow',
#  'said': 'say',
#  'hit': 'hit',
#  'gave': 'give',
#  'whole': 'whole',
#  'new': 'new',
#  'outlook': 'outlook',
#  'creative': 'creative',
#  'it.': 'it.',
#  'cause': 'cause',
#  'create': 'create',
#  'going': 'go',
#  'permits': 'permit',
#  'force': 'force',
#  'used': 'use',
#  'to.': 'to.',
#  'became': 'become',
#  'one': 'one',
#  'four': 'four',
#  'top': 'top',
#  '10': '10',
#  'hits': 'hit',
#  'collaboration': 'collaboration',
#  'peaked': 'peak',
#  '2': '2',
#  'billboard': 'billboard',
#  '100': '100',
#  'making': 'make',
#  'highest-charting': 'highest-charting',
#  'featured': 'feature',
#  'appearance': 'appearance',
#  'track': 'track',
#  'later': 'later',
#  'certified': 'certify',
#  'double': 'double',
#  'platinum': 'platinum',
#  'december': 'december',
#  '2007.': '2007.',
#  'watch': 'watch',
#  'full': 'full',
#  'read': 'read',
#  'lyrics': 'lyric',
#  'featuring': 'feature',
#  'genius': 'genius'}
